# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from keras.callbacks import EarlyStopping

# %%
# Parameters
stocks = 'TSLA'
start_date = '2014-01-01'
end_date = '2024-12-31'
input_days_list = [60, 30, 10, 5]  # Different input days for training

# %%
# Download stock data
df = yf.download(stocks, start=start_date, end=end_date)
df.reset_index(inplace=True)

# Data Preparation
features = df['Close'].values
features = features.astype('float32')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Plotting the closing price
plt.figure(figsize=(16, 6))
plt.plot(df['Date'], df['Close'], color='blue')
plt.title('Close Price History')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.xticks(rotation=45)
plt.show()

# %%
# Normalize the features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features.reshape(-1, 1))

# Prepare sequences
training_data_len = int(np.ceil(len(scaled_features) * 0.8))

# %%
# Create a function to train, predict, and visualize with various input days
def train_and_predict(input_days):
    # Create training data
    train_data = scaled_features[:training_data_len]
    x_train, y_train = [], []

    for i in range(input_days, len(train_data)):
        x_train.append(train_data[i-input_days:i])
        y_train.append(train_data[i])

    x_train = np.array(x_train)
    y_train = np.array(y_train)

    # Reshape x_train for LSTM
    x_train = x_train.reshape(-1, input_days, 1)

    # Create testing data
    test_data = scaled_features[training_data_len - input_days:]
    x_test, y_test = [], []

    for i in range(input_days, len(test_data)):
        x_test.append(test_data[i-input_days:i])
        y_test.append(test_data[i])

    x_test = np.array(x_test)
    y_test = np.array(y_test)

    # Reshape x_test for LSTM
    x_test = x_test.reshape(-1, input_days, 1)

    # Initialize and compile the model
    model = Sequential()
    model.add(LSTM(512, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(256, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(25))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mean_squared_error')

    # Fit the model
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test), verbose=1, shuffle=False)

    # Make predictions
    train_predictions = model.predict(x_train)
    test_predictions = model.predict(x_test)

    # Inverse transform the predictions to get the actual prices
    train_predictions = scaler.inverse_transform(train_predictions)
    test_predictions = scaler.inverse_transform(test_predictions)

    # Visualization of Predictions
    train = df[:training_data_len]
    valid = df[training_data_len:].copy()
    valid['Predictions'] = test_predictions.flatten()

    plt.figure(figsize=(16, 6))
    plt.title(f'LSTM Model Predictions with {input_days} Days Input')
    plt.xlabel('Date', fontsize=18)
    plt.ylabel('Close Price USD ($)', fontsize=18)
    plt.plot(train['Date'], train['Close'], label='Train')
    plt.plot(valid['Date'], valid['Close'], label='Val', color='green')
    plt.plot(valid['Date'], valid['Predictions'], label='Predictions', color='orange')
    plt.legend(loc='lower right')
    plt.show()

    # Calculate performance metrics
    mse = mean_squared_error(valid['Close'], valid['Predictions'])
    mae = mean_absolute_error(valid['Close'], valid['Predictions'])
    rmse = np.sqrt(mse)
    r2 = r2_score(valid['Close'], valid['Predictions'])

    print(f"Performance metrics for input days {input_days}:")
    print(f"R² Score: {r2:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print("\n")

    # Plot train and validation loss
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Train Loss', color='blue')
    plt.plot(history.history['val_loss'], label='Validation Loss', color='green')
    plt.title(f'Model Train vs Validation Loss with {input_days} Days Input')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

    # Predict the next day using the last input_days
    last_input_days = scaled_features[-input_days:]
    last_input_days = last_input_days.reshape((1, input_days, 1))

    predicted_price = model.predict(last_input_days)
    predicted_price = scaler.inverse_transform(predicted_price)

    # Display the next day's predicted price
    next_day_date = df['Date'].iloc[-1] + pd.Timedelta(days=1)
    predicted_df = pd.DataFrame(data=predicted_price, index=[next_day_date], columns=['Predicted Close'])

    print(f"Predicted stock price for {next_day_date.date()} (using last {input_days} days): ${predicted_price[0][0]:.2f}")

    # Plotting the results
    plt.figure(figsize=(10, 5))
    plt.plot(df['Date'], df['Close'], label='Historical Close Prices', color='blue')
    plt.axvline(x=next_day_date, color='orange', linestyle='--', label='Prediction Date')
    plt.scatter(next_day_date, predicted_price, color='red', label='Predicted Price', s=100)

    # Add titles and labels
    plt.title('Predicted Next Day Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price in USD')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Loop through different input lengths
for input_days in input_days_list:
    train_and_predict(input_days)
# Out:
# c:\Users\ben\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - loss: 0.0014 - val_loss: 0.0052
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - loss: 0.0068 - val_loss: 0.0096
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - loss: 0.0130 - val_loss: 0.0075
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 154ms/step - loss: 0.0105 - val_loss: 0.0075
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - loss: 0.0210 - val_loss: 0.0057
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - loss: 0.0140 - val_loss: 0.0045
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 0.0104 - val_loss: 0.0037
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - loss: 5.7908e-04 - val_loss: 0.0021
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 139ms/step - loss: 5.8545e-04 - val_loss: 0.0022
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 139ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - loss: 9.3868e-04 - val_loss: 0.0023
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - loss: 9.4863e-04 - val_loss: 0.0028
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - loss: 8.5148e-04 - val_loss: 0.0022
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - loss: 6.8384e-04 - val_loss: 0.0023
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - loss: 7.9071e-04 - val_loss: 0.0027
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - loss: 8.7736e-04 - val_loss: 0.0026
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - loss: 9.5720e-04 - val_loss: 0.0024
# Epoch 31/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - loss: 8.2535e-04 - val_loss: 0.0024
# Epoch 32/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - loss: 7.8145e-04 - val_loss: 0.0026
# Epoch 33/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - loss: 9.2465e-04 - val_loss: 0.0023
# Epoch 34/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - loss: 6.9995e-04 - val_loss: 0.0024
# Epoch 35/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - loss: 8.0121e-04 - val_loss: 0.0025
# Epoch 36/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 37/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 38/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 39/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - loss: 8.4193e-04 - val_loss: 0.0020
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - loss: 8.5215e-04 - val_loss: 0.0018
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - loss: 7.2972e-04 - val_loss: 0.0019
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - loss: 8.8916e-04 - val_loss: 0.0017
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - loss: 5.1886e-04 - val_loss: 0.0020
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - loss: 5.0340e-04 - val_loss: 0.0019
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - loss: 5.4063e-04 - val_loss: 0.0015
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - loss: 4.6217e-04 - val_loss: 0.0016
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# Performance metrics for input days 60:
# R² Score: 0.8959
# Mean Absolute Error (MAE): 12.3222
# Mean Squared Error (MSE): 344.4414
# Root Mean Squared Error (RMSE): 18.5591
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted stock price for 2024-12-31 (using last 60 days): $353.41
# Epoch 1/50
# c:\Users\ben\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - loss: 0.0018 - val_loss: 0.0043
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 0.0094 - val_loss: 0.0027
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 0.0068 - val_loss: 0.0033
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.0069 - val_loss: 0.0039
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.0069 - val_loss: 0.0033
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 1.6187e-04 - val_loss: 0.0011
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 0.0011 - val_loss: 8.7771e-04
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 1.6910e-04 - val_loss: 8.3796e-04
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 2.9777e-04 - val_loss: 7.8625e-04
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 3.4779e-04 - val_loss: 9.4573e-04
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 5.9564e-04 - val_loss: 9.0023e-04
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 6.3553e-04 - val_loss: 8.1194e-04
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 3.9493e-04 - val_loss: 9.1653e-04
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 7.4716e-04 - val_loss: 0.0011
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0057 - val_loss: 0.0033
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 0.0041 - val_loss: 0.0022
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 0.0041 - val_loss: 0.0025
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.0048 - val_loss: 0.0020
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0018 - val_loss: 5.9368e-04
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 2.3767e-04 - val_loss: 6.1638e-04
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 4.3037e-04 - val_loss: 5.9966e-04
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 1.2573e-04 - val_loss: 6.3216e-04
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.9948e-04 - val_loss: 5.5450e-04
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 2.5558e-04 - val_loss: 4.6260e-04
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 1.1790e-04 - val_loss: 4.8309e-04
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 1.5657e-04 - val_loss: 4.9154e-04
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 1.2162e-04 - val_loss: 8.0275e-04
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 2.1476e-04 - val_loss: 6.2921e-04
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 1.9534e-04 - val_loss: 5.8056e-04
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 1.3357e-04 - val_loss: 4.3297e-04
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 1.3218e-04 - val_loss: 6.6340e-04
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 1.4810e-04 - val_loss: 4.8220e-04
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 1.3103e-04 - val_loss: 4.1654e-04
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 6.2096e-04 - val_loss: 5.9243e-04
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 1.5883e-04 - val_loss: 4.4510e-04
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 9.2937e-05 - val_loss: 4.5009e-04
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 2.5149e-04 - val_loss: 9.8884e-04
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 4.5029e-04 - val_loss: 9.2011e-04
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 4.8498e-04 - val_loss: 7.9940e-04
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 3.1936e-04 - val_loss: 9.4141e-04
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 6.7889e-04 - val_loss: 7.6030e-04
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# Performance metrics for input days 30:
# R² Score: 0.9491
# Mean Absolute Error (MAE): 8.8290
# Mean Squared Error (MSE): 168.3586
# Root Mean Squared Error (RMSE): 12.9753
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted stock price for 2024-12-31 (using last 30 days): $381.78
# Epoch 1/50
# c:\Users\ben\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 7.5879e-04 - val_loss: 0.0223
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0141 - val_loss: 0.0077
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0084 - val_loss: 0.0055
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0107 - val_loss: 0.0073
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0188 - val_loss: 0.0048
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0106 - val_loss: 0.0024
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.0430e-04 - val_loss: 0.0016
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.7812e-04 - val_loss: 0.0023
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.4437e-04 - val_loss: 0.0017
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 5.2244e-04 - val_loss: 0.0016
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.5620e-04 - val_loss: 0.0014
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 5.7203e-04 - val_loss: 0.0012
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3.9173e-04 - val_loss: 0.0013
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.1493e-04 - val_loss: 0.0012
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.5652e-04 - val_loss: 0.0011
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.2360e-04 - val_loss: 8.0367e-04
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.1617e-04 - val_loss: 6.3125e-04
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0012 - val_loss: 7.6031e-04
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0013 - val_loss: 6.7974e-04
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.4713e-04 - val_loss: 0.0010
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.7219e-04 - val_loss: 0.0012
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.4492e-04 - val_loss: 8.8824e-04
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.0376e-04 - val_loss: 6.0579e-04
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.6596e-04 - val_loss: 6.4968e-04
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.1398e-04 - val_loss: 5.4995e-04
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.3160e-04 - val_loss: 7.5425e-04
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 8.2686e-05 - val_loss: 4.7243e-04
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3.8355e-04 - val_loss: 4.6689e-04
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.8827e-04 - val_loss: 0.0031
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0022 - val_loss: 0.0038
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0042 - val_loss: 0.0025
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0036 - val_loss: 8.2669e-04
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.5309e-04 - val_loss: 7.6654e-04
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.7784e-04 - val_loss: 8.7486e-04
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.1489e-04 - val_loss: 7.8418e-04
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.3027e-04 - val_loss: 7.2771e-04
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.9365e-04 - val_loss: 7.6273e-04
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 2.3196e-04 - val_loss: 6.2497e-04
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.3656e-04 - val_loss: 6.4318e-04
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.2594e-04 - val_loss: 6.9697e-04
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.2731e-04 - val_loss: 6.3458e-04
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.4085e-04 - val_loss: 6.4826e-04
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Performance metrics for input days 10:
# R² Score: 0.9566
# Mean Absolute Error (MAE): 7.7919
# Mean Squared Error (MSE): 143.5481
# Root Mean Squared Error (RMSE): 11.9812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted stock price for 2024-12-31 (using last 10 days): $383.74
# Epoch 1/50
# c:\Users\ben\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 5.5238e-04 - val_loss: 0.0043
# Epoch 2/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0080 - val_loss: 0.0065
# Epoch 3/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 4/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0121 - val_loss: 0.0050
# Epoch 5/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0081 - val_loss: 0.0032
# Epoch 6/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 7/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5448e-04 - val_loss: 0.0018
# Epoch 8/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.2428e-04 - val_loss: 0.0016
# Epoch 9/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6423e-04 - val_loss: 0.0014
# Epoch 10/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3707e-04 - val_loss: 0.0015
# Epoch 11/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3863e-04 - val_loss: 0.0012
# Epoch 12/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.7181e-04 - val_loss: 0.0011
# Epoch 13/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 14/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 15/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 16/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.7654e-04 - val_loss: 0.0015
# Epoch 17/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.8884e-04 - val_loss: 0.0014
# Epoch 18/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7924e-04 - val_loss: 0.0011
# Epoch 19/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.5366e-04 - val_loss: 9.7884e-04
# Epoch 20/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 21/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3190e-04 - val_loss: 8.2411e-04
# Epoch 22/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.1599e-04 - val_loss: 0.0016
# Epoch 23/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 24/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.6120e-04 - val_loss: 8.9171e-04
# Epoch 25/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6601e-04 - val_loss: 0.0013
# Epoch 26/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 27/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 28/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3100e-04 - val_loss: 0.0013
# Epoch 29/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 30/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6337e-04 - val_loss: 0.0016
# Epoch 31/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.1988e-04 - val_loss: 0.0015
# Epoch 32/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0853e-04 - val_loss: 7.4866e-04
# Epoch 33/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3712e-04 - val_loss: 0.0013
# Epoch 34/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0052 - val_loss: 0.0075
# Epoch 35/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 36/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 37/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0098 - val_loss: 0.0031
# Epoch 38/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 39/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3838e-04 - val_loss: 0.0018
# Epoch 40/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9273e-04 - val_loss: 0.0020
# Epoch 41/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7827e-04 - val_loss: 0.0028
# Epoch 42/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0010 - val_loss: 0.0032
# Epoch 43/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.5502e-04 - val_loss: 0.0032
# Epoch 44/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0285e-04 - val_loss: 0.0032
# Epoch 45/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5522e-04 - val_loss: 0.0037
# Epoch 46/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.1937e-04 - val_loss: 0.0041
# Epoch 47/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.9437e-04 - val_loss: 0.0044
# Epoch 48/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.8813e-04 - val_loss: 0.0047
# Epoch 49/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - val_loss: 0.0047
# Epoch 50/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.9622e-04 - val_loss: 0.0062
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Performance metrics for input days 5:
# R² Score: 0.5883
# Mean Absolute Error (MAE): 23.1218
# Mean Squared Error (MSE): 1362.2894
# Root Mean Squared Error (RMSE): 36.9092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted stock price for 2024-12-31 (using last 5 days): $278.34
