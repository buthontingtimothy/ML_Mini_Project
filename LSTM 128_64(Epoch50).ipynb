# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from keras.callbacks import EarlyStopping

# %%
# Parameters
stocks = 'TSLA'
start_date = '2014-01-01'
end_date = '2024-12-31'
input_days_list = [60, 30, 10, 5]  # Different input days for training

# %%
# Download stock data
df = yf.download(stocks, start=start_date, end=end_date)
df.reset_index(inplace=True)

# Data Preparation
features = df['Close'].values
features = features.astype('float32')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Plotting the closing price
plt.figure(figsize=(16, 6))
plt.plot(df['Date'], df['Close'], color='blue')
plt.title('Close Price History')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.xticks(rotation=45)
plt.show()

# %%
# Normalize the features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features.reshape(-1, 1))

# Prepare sequences
training_data_len = int(np.ceil(len(scaled_features) * 0.8))

# %%
# Create a function to train, predict, and visualize with various input days
def train_and_predict(input_days):
    # Create training data
    train_data = scaled_features[:training_data_len]
    x_train, y_train = [], []

    for i in range(input_days, len(train_data)):
        x_train.append(train_data[i-input_days:i])
        y_train.append(train_data[i])

    x_train = np.array(x_train)
    y_train = np.array(y_train)

    # Reshape x_train for LSTM
    x_train = x_train.reshape(-1, input_days, 1)

    # Create testing data
    test_data = scaled_features[training_data_len - input_days:]
    x_test, y_test = [], []

    for i in range(input_days, len(test_data)):
        x_test.append(test_data[i-input_days:i])
        y_test.append(test_data[i])

    x_test = np.array(x_test)
    y_test = np.array(y_test)

    # Reshape x_test for LSTM
    x_test = x_test.reshape(-1, input_days, 1)

    # Initialize and compile the model
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(64, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(25))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mean_squared_error')

    # Fit the model
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test), verbose=1, shuffle=False)

    # Make predictions
    train_predictions = model.predict(x_train)
    test_predictions = model.predict(x_test)

    # Inverse transform the predictions to get the actual prices
    train_predictions = scaler.inverse_transform(train_predictions)
    test_predictions = scaler.inverse_transform(test_predictions)

    # Visualization of Predictions
    train = df[:training_data_len]
    valid = df[training_data_len:].copy()
    valid['Predictions'] = test_predictions.flatten()

    plt.figure(figsize=(16, 6))
    plt.title(f'LSTM Model Predictions with {input_days} Days Input')
    plt.xlabel('Date', fontsize=18)
    plt.ylabel('Close Price USD ($)', fontsize=18)
    plt.plot(train['Date'], train['Close'], label='Train')
    plt.plot(valid['Date'], valid['Close'], label='Val', color='green')
    plt.plot(valid['Date'], valid['Predictions'], label='Predictions', color='orange')
    plt.legend(loc='lower right')
    plt.show()

    # Calculate performance metrics
    mse = mean_squared_error(valid['Close'], valid['Predictions'])
    mae = mean_absolute_error(valid['Close'], valid['Predictions'])
    rmse = np.sqrt(mse)
    r2 = r2_score(valid['Close'], valid['Predictions'])

    print(f"Performance metrics for input days {input_days}:")
    print(f"R² Score: {r2:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print("\n")

    # Plot train and validation loss
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Train Loss', color='blue')
    plt.plot(history.history['val_loss'], label='Validation Loss', color='green')
    plt.title(f'Model Train vs Validation Loss with {input_days} Days Input')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

    # Predict the next day using the last input_days
    last_input_days = scaled_features[-input_days:]
    last_input_days = last_input_days.reshape((1, input_days, 1))

    predicted_price = model.predict(last_input_days)
    predicted_price = scaler.inverse_transform(predicted_price)

    # Display the next day's predicted price
    next_day_date = df['Date'].iloc[-1] + pd.Timedelta(days=1)
    predicted_df = pd.DataFrame(data=predicted_price, index=[next_day_date], columns=['Predicted Close'])

    print(f"Predicted stock price for {next_day_date.date()} (using last {input_days} days): ${predicted_price[0][0]:.2f}")

    # Plotting the results
    plt.figure(figsize=(10, 5))
    plt.plot(df['Date'], df['Close'], label='Historical Close Prices', color='blue')
    plt.axvline(x=next_day_date, color='orange', linestyle='--', label='Prediction Date')
    plt.scatter(next_day_date, predicted_price, color='red', label='Predicted Price', s=100)

    # Add titles and labels
    plt.title('Predicted Next Day Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price in USD')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Loop through different input lengths
for input_days in input_days_list:
    train_and_predict(input_days)
# Out:
# Epoch 1/50
# c:\Users\ben\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 5.3370e-04 - val_loss: 0.0077
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0070 - val_loss: 0.0042
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0081 - val_loss: 0.0055
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0125 - val_loss: 0.0049
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0127 - val_loss: 0.0042
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0086 - val_loss: 0.0039
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0054 - val_loss: 0.0044
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0064 - val_loss: 0.0049
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0069 - val_loss: 0.0056
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0072 - val_loss: 0.0086
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0074 - val_loss: 0.0240
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0040 - val_loss: 0.0123
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0010 - val_loss: 0.0078
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0037 - val_loss: 0.0077
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.2595e-04 - val_loss: 0.0052
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0010 - val_loss: 0.0039
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 7.0604e-04 - val_loss: 0.0040
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.9578e-04 - val_loss: 0.0042
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4.2178e-04 - val_loss: 0.0046
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.8694e-04 - val_loss: 0.0040
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.1306e-04 - val_loss: 0.0042
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.9502e-04 - val_loss: 0.0039
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.4042e-04 - val_loss: 0.0053
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.9059e-04 - val_loss: 0.0057
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0010 - val_loss: 0.0052
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0013 - val_loss: 0.0073
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0018 - val_loss: 0.0069
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 31/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.7808e-04 - val_loss: 0.0078
# Epoch 32/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0013 - val_loss: 0.0054
# Epoch 33/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 6.9598e-04 - val_loss: 0.0058
# Epoch 34/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.8458e-04 - val_loss: 0.0055
# Epoch 35/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 6.2937e-04 - val_loss: 0.0050
# Epoch 36/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 6.4163e-04 - val_loss: 0.0059
# Epoch 37/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 8.3741e-04 - val_loss: 0.0049
# Epoch 38/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 7.3870e-04 - val_loss: 0.0065
# Epoch 39/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0014 - val_loss: 0.0060
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0021 - val_loss: 0.0054
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0026 - val_loss: 0.0058
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0035 - val_loss: 0.0049
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0045 - val_loss: 0.0063
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0047 - val_loss: 0.0121
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0033 - val_loss: 0.0131
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0014 - val_loss: 0.0074
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0025 - val_loss: 0.0050
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 5.7305e-04 - val_loss: 0.0030
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.3267e-04 - val_loss: 0.0038
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Performance metrics for input days 60:
# R² Score: 0.7428
# Mean Absolute Error (MAE): 27.6385
# Mean Squared Error (MSE): 851.0045
# Root Mean Squared Error (RMSE): 29.1720
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Predicted stock price for 2024-12-31 (using last 60 days): $399.24
# Epoch 1/50
# c:\Users\ben\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 4.8795e-04 - val_loss: 0.0069
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0087 - val_loss: 0.0052
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0124 - val_loss: 0.0060
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0093 - val_loss: 0.0061
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0084 - val_loss: 0.0063
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0062 - val_loss: 0.0056
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0052 - val_loss: 0.0071
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0050 - val_loss: 0.0138
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0038 - val_loss: 0.0213
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.9729e-04 - val_loss: 0.0109
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0094 - val_loss: 0.0152
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0022 - val_loss: 0.0060
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.3642e-04 - val_loss: 0.0040
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0010 - val_loss: 0.0031
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.0377e-04 - val_loss: 0.0033
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0199e-04 - val_loss: 0.0030
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6348e-04 - val_loss: 0.0042
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.0353e-04 - val_loss: 0.0046
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.4937e-04 - val_loss: 0.0046
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.3104e-04 - val_loss: 0.0052
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.7255e-04 - val_loss: 0.0054
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.7316e-04 - val_loss: 0.0065
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 0.0049
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.7032e-04 - val_loss: 0.0048
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.4865e-04 - val_loss: 0.0045
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9931e-04 - val_loss: 0.0047
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.8285e-04 - val_loss: 0.0047
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.8856e-04 - val_loss: 0.0045
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3826e-04 - val_loss: 0.0037
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2596e-04 - val_loss: 0.0058
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - val_loss: 0.0057
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 0.0056
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0056
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0071
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 0.0069
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 0.0085
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.1381e-04 - val_loss: 0.0055
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.6889e-04 - val_loss: 0.0040
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - val_loss: 0.0037
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9772e-04 - val_loss: 0.0034
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0134e-04 - val_loss: 0.0038
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.5028e-04 - val_loss: 0.0035
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6809e-04 - val_loss: 0.0040
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5034e-04 - val_loss: 0.0027
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.5869e-04 - val_loss: 0.0034
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.6556e-04 - val_loss: 0.0051
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 0.0037
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Performance metrics for input days 30:
# R² Score: 0.7510
# Mean Absolute Error (MAE): 26.0889
# Mean Squared Error (MSE): 823.9134
# Root Mean Squared Error (RMSE): 28.7039
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicted stock price for 2024-12-31 (using last 30 days): $376.21
# Epoch 1/50
# c:\Users\ben\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 3.8793e-04 - val_loss: 0.0062
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0118 - val_loss: 0.0051
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0119 - val_loss: 0.0076
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0098 - val_loss: 0.0064
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0089 - val_loss: 0.0060
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0096 - val_loss: 0.0068
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0099 - val_loss: 0.0124
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0087 - val_loss: 0.0343
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0041 - val_loss: 0.0109
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0043 - val_loss: 0.0066
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0016 - val_loss: 0.0049
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.3677e-04 - val_loss: 0.0042
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.1208e-04 - val_loss: 0.0035
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5993e-04 - val_loss: 0.0044
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8915e-04 - val_loss: 0.0063
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7602e-04 - val_loss: 0.0076
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.4779e-04 - val_loss: 0.0054
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2897e-04 - val_loss: 0.0060
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.2192e-04 - val_loss: 0.0053
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.3445e-04 - val_loss: 0.0068
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.4127e-04 - val_loss: 0.0081
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2147e-04 - val_loss: 0.0065
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2487e-04 - val_loss: 0.0059
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.0125e-04 - val_loss: 0.0075
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.4787e-04 - val_loss: 0.0056
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2159e-04 - val_loss: 0.0062
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.2738e-04 - val_loss: 0.0064
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.8734e-04 - val_loss: 0.0063
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.3283e-04 - val_loss: 0.0057
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.4683e-04 - val_loss: 0.0061
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.1532e-04 - val_loss: 0.0061
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.3488e-04 - val_loss: 0.0056
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.2341e-04 - val_loss: 0.0066
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.6324e-04 - val_loss: 0.0059
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4681e-04 - val_loss: 0.0070
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.9617e-04 - val_loss: 0.0096
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0012 - val_loss: 0.0071
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.6573e-04 - val_loss: 0.0065
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.6867e-04 - val_loss: 0.0059
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.8156e-04 - val_loss: 0.0075
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.1876e-04 - val_loss: 0.0051
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.0841e-04 - val_loss: 0.0071
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.4195e-04 - val_loss: 0.0054
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2906e-04 - val_loss: 0.0063
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.3455e-04 - val_loss: 0.0052
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.4084e-04 - val_loss: 0.0051
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.8233e-04 - val_loss: 0.0067
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0010 - val_loss: 0.0054
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7503e-04 - val_loss: 0.0075
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0012 - val_loss: 0.0052
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Performance metrics for input days 10:
# R² Score: 0.6488
# Mean Absolute Error (MAE): 31.7359
# Mean Squared Error (MSE): 1162.1004
# Root Mean Squared Error (RMSE): 34.0896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted stock price for 2024-12-31 (using last 10 days): $377.24
# Epoch 1/50
# c:\Users\ben\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 8.6812e-04 - val_loss: 0.0059
# Epoch 2/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - val_loss: 0.0070
# Epoch 3/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0226 - val_loss: 0.0179
# Epoch 4/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0291 - val_loss: 0.0510
# Epoch 5/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0317 - val_loss: 0.0046
# Epoch 6/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - val_loss: 0.0024
# Epoch 7/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 8/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 9/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 10/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 11/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - val_loss: 0.0044
# Epoch 12/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 13/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 0.0050
# Epoch 14/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - val_loss: 0.0108
# Epoch 15/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 16/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1683e-04 - val_loss: 0.0051
# Epoch 17/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5817e-04 - val_loss: 0.0035
# Epoch 18/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5508e-04 - val_loss: 0.0052
# Epoch 19/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7898e-04 - val_loss: 0.0049
# Epoch 20/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8829e-04 - val_loss: 0.0051
# Epoch 21/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6764e-04 - val_loss: 0.0044
# Epoch 22/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7684e-04 - val_loss: 0.0061
# Epoch 23/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3718e-04 - val_loss: 0.0044
# Epoch 24/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5700e-04 - val_loss: 0.0067
# Epoch 25/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4732e-04 - val_loss: 0.0078
# Epoch 26/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 0.0082
# Epoch 27/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 0.0062
# Epoch 28/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6088e-04 - val_loss: 0.0064
# Epoch 29/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5551e-04 - val_loss: 0.0061
# Epoch 30/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4481e-04 - val_loss: 0.0073
# Epoch 31/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9195e-04 - val_loss: 0.0048
# Epoch 32/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010 - val_loss: 0.0093
# Epoch 33/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - val_loss: 0.0044
# Epoch 34/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3402e-04 - val_loss: 0.0072
# Epoch 35/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 36/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - val_loss: 0.0070
# Epoch 37/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - val_loss: 0.0059
# Epoch 38/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - val_loss: 0.0072
# Epoch 39/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 40/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - val_loss: 0.0077
# Epoch 41/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - val_loss: 0.0121
# Epoch 42/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0107
# Epoch 43/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - val_loss: 0.0077
# Epoch 44/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 45/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 0.0039
# Epoch 46/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8363e-04 - val_loss: 0.0043
# Epoch 47/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5640e-04 - val_loss: 0.0026
# Epoch 48/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2897e-04 - val_loss: 0.0034
# Epoch 49/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2569e-04 - val_loss: 0.0042
# Epoch 50/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4170e-04 - val_loss: 0.0034
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Performance metrics for input days 5:
# R² Score: 0.7722
# Mean Absolute Error (MAE): 25.3057
# Mean Squared Error (MSE): 753.5819
# Root Mean Squared Error (RMSE): 27.4514
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted stock price for 2024-12-31 (using last 5 days): $395.02
